# %%
# !nvidia-smi
# Out:
# Thu Jun  2 12:09:05 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
import shutil
import os

#현재 폴더 경로; 작업 폴더 기준
print(os.getcwd())
shutil.copy('/content/gdrive/MyDrive/Colab Notebooks/cityspaces/cityscapes_data.zip', './cityspaces_data.zip')
# Out:
# /content
# './cityspaces_data.zip'

# %%
# !unzip cityspaces_data.zip
# Out:
# Archive:  cityspaces_data.zip
#   inflating: train/1.jpg
#   inflating: train/10.jpg
#   inflating: train/100.jpg
#   inflating: train/1000.jpg
#   inflating: train/1001.jpg
#   inflating: train/1002.jpg
#   inflating: train/1003.jpg
#   inflating: train/1004.jpg
#   inflating: train/1005.jpg
#   inflating: train/1006.jpg
#   inflating: train/1007.jpg
#   inflating: train/1008.jpg
#   inflating: train/1009.jpg
#   inflating: train/101.jpg
#   inflating: train/1010.jpg
#   inflating: train/1011.jpg
#   inflating: train/1012.jpg
#   inflating: train/1013.jpg
#   inflating: train/1014.jpg
#   inflating: train/1015.jpg
#   inflating: train/1016.jpg
#   inflating: train/1017.jpg
#   inflating: train/1018.jpg
#   inflating: train/1019.jpg
#   inflating: train/102.jpg
#   inflating: train/1020.jpg
#   inflating: train/1021.jpg
#   inflating: train/1022.jpg
#   inflating: train/1023.jpg
#   inflating: train/1024.jpg
#   inflating: train/1025.jpg
#   inflating: train/1026.jpg
#   inflating: train/1027.jpg
#   inflating: train/1028.jpg
#   inflating: train/1029.jpg
#   inflating: train/103.jpg
#   inflating: train/1030.jpg
#   inflating: train/1031.jpg
#   inflating: train/1032.jpg
#   inflating: train/1033.jpg
#   inflating: train/1034.jpg
#   inflating: train/1035.jpg
#   inflating: train/1036.jpg
#   inflating: train/1037.jpg
#   inflating: train/1038.jpg
#   inflating: train/1039.jpg
#   inflating: train/104.jpg
#   inflating: train/1040.jpg
#   inflating: train/1041.jpg
#   inflating: train/1042.jpg
#   inflating: train/1043.jpg
#   inflating: train/1044.jpg
#   inflating: train/1045.jpg
#   inflating: train/1046.jpg
#   inflating: train/1047.jpg
#   inflating: train/1048.jpg
#   inflating: train/1049.jpg
#   inflating: train/105.jpg
#   inflating: train/1050.jpg
#   inflating: train/1051.jpg
#   inflating: train/1052.jpg
#   inflating: train/1053.jpg
#   inflating: train/1054.jpg
#   inflating: train/1055.jpg
#   inflating: train/1056.jpg
#   inflating: train/1057.jpg
#   inflating: train/1058.jpg
#   inflating: train/1059.jpg
#   inflating: train/106.jpg
#   inflating: train/1060.jpg
#   inflating: train/1061.jpg
#   inflating: train/1062.jpg
#   inflating: train/1063.jpg
#   inflating: train/1064.jpg
#   inflating: train/1065.jpg
#   inflating: train/1066.jpg
#   inflating: train/1067.jpg
#   inflating: train/1068.jpg
#   inflating: train/1069.jpg
#   inflating: train/107.jpg
#   inflating: train/1070.jpg
#   inflating: train/1071.jpg
#   inflating: train/1072.jpg
#   inflating: train/1073.jpg
#   inflating: train/1074.jpg
#   inflating: train/1075.jpg
#   inflating: train/1076.jpg
#   inflating: train/1077.jpg
#   inflating: train/1078.jpg
#   inflating: train/1079.jpg
#   inflating: train/108.jpg
#   inflating: train/1080.jpg
#   inflating: train/1081.jpg
#   inflating: train/1082.jpg
#   inflating: train/1083.jpg
#   inflating: train/1084.jpg
#   inflating: train/1085.jpg
#   inflating: train/1086.jpg
#   inflating: train/1087.jpg
#   inflating: train/1088.jpg
#   inflating: train/1089.jpg
#   inflating: train/109.jpg
#   inflating: train/1090.jpg
#   inflating: train/1091.jpg
#   inflating: train/1092.jpg
#   inflating: train/1093.jpg
#   inflating: train/1094.jpg
#   inflating: train/1095.jpg
#   inflating: train/1096.jpg
#   inflating: train/1097.jpg
#   inflating: train/1098.jpg
#   inflating: train/1099.jpg
#   inflating: train/11.jpg
#   inflating: train/110.jpg
#   inflating: train/1100.jpg
#   inflating: train/1101.jpg
#   inflating: train/1102.jpg
#   inflating: train/1103.jpg
#   inflating: train/1104.jpg
#   inflating: train/1105.jpg
#   inflating: train/1106.jpg
#   inflating: train/1107.jpg
#   inflating: train/1108.jpg
#   inflating: train/1109.jpg
#   inflating: train/111.jpg
#   inflating: train/1110.jpg
#   inflating: train/1111.jpg
#   inflating: train/1112.jpg
#   inflating: train/1113.jpg
#   inflating: train/1114.jpg
#   inflating: train/1115.jpg
#   inflating: train/1116.jpg
#   inflating: train/1117.jpg
#   inflating: train/1118.jpg
#   inflating: train/1119.jpg
#   inflating: train/112.jpg
#   inflating: train/1120.jpg
#   inflating: train/1121.jpg
#   inflating: train/1122.jpg
#   inflating: train/1123.jpg
#   inflating: train/1124.jpg
#   inflating: train/1125.jpg
#   inflating: train/1126.jpg
#   inflating: train/1127.jpg
#   inflating: train/1128.jpg
#   inflating: train/1129.jpg
#   inflating: train/113.jpg
#   inflating: train/1130.jpg
#   inflating: train/1131.jpg
#   inflating: train/1132.jpg
#   inflating: train/1133.jpg
#   inflating: train/1134.jpg
#   inflating: train/1135.jpg
#   inflating: train/1136.jpg
#   inflating: train/1137.jpg
#   inflating: train/1138.jpg
#   inflating: train/1139.jpg
#   inflating: train/114.jpg
#   inflating: train/1140.jpg
#   inflating: train/1141.jpg
#   inflating: train/1142.jpg
#   inflating: train/1143.jpg
#   inflating: train/1144.jpg
#   inflating: train/1145.jpg
#   inflating: train/1146.jpg
#   inflating: train/1147.jpg
#   inflating: train/1148.jpg
#   inflating: train/1149.jpg
#   inflating: train/115.jpg
#   inflating: train/1150.jpg
#   inflating: train/1151.jpg
#   inflating: train/1152.jpg
#   inflating: train/1153.jpg
#   inflating: train/1154.jpg
#   inflating: train/1155.jpg
#   inflating: train/1156.jpg
#   inflating: train/1157.jpg
#   inflating: train/1158.jpg
#   inflating: train/1159.jpg
#   inflating: train/116.jpg
#   inflating: train/1160.jpg
#   inflating: train/1161.jpg
#   inflating: train/1162.jpg
#   inflating: train/1163.jpg
#   inflating: train/1164.jpg
#   inflating: train/1165.jpg
#   inflating: train/1166.jpg
#   inflating: train/1167.jpg
#   inflating: train/1168.jpg
#   inflating: train/1169.jpg
#   inflating: train/117.jpg
#   inflating: train/1170.jpg
#   inflating: train/1171.jpg
#   inflating: train/1172.jpg
#   inflating: train/1173.jpg
#   inflating: train/1174.jpg
#   inflating: train/1175.jpg
#   inflating: train/1176.jpg
#   inflating: train/1177.jpg
#   inflating: train/1178.jpg
#   inflating: train/1179.jpg
#   inflating: train/118.jpg
#   inflating: train/1180.jpg
#   inflating: train/1181.jpg
#   inflating: train/1182.jpg
#   inflating: train/1183.jpg
#   inflating: train/1184.jpg
#   inflating: train/1185.jpg
#   inflating: train/1186.jpg
#   inflating: train/1187.jpg
#   inflating: train/1188.jpg
#   inflating: train/1189.jpg
#   inflating: train/119.jpg
#   inflating: train/1190.jpg
#   inflating: train/1191.jpg
#   inflating: train/1192.jpg
#   inflating: train/1193.jpg
#   inflating: train/1194.jpg
#   inflating: train/1195.jpg
#   inflating: train/1196.jpg
#   inflating: train/1197.jpg
#   inflating: train/1198.jpg
#   inflating: train/1199.jpg
#   inflating: train/12.jpg
#   inflating: train/120.jpg
#   inflating: train/1200.jpg
#   inflating: train/1201.jpg
#   inflating: train/1202.jpg
#   inflating: train/1203.jpg
#   inflating: train/1204.jpg
#   inflating: train/1205.jpg
#   inflating: train/1206.jpg
#   inflating: train/1207.jpg
#   inflating: train/1208.jpg
#   inflating: train/1209.jpg
#   inflating: train/121.jpg
#   inflating: train/1210.jpg
#   inflating: train/1211.jpg
#   inflating: train/1212.jpg
#   inflating: train/1213.jpg
#   inflating: train/1214.jpg
#   inflating: train/1215.jpg
#   inflating: train/1216.jpg
#   inflating: train/1217.jpg
#   inflating: train/1218.jpg
#   inflating: train/1219.jpg
#   inflating: train/122.jpg
#   inflating: train/1220.jpg
#   inflating: train/1221.jpg
#   inflating: train/1222.jpg
#   inflating: train/1223.jpg
#   inflating: train/1224.jpg
#   inflating: train/1225.jpg
#   inflating: train/1226.jpg
#   inflating: train/1227.jpg
#   inflating: train/1228.jpg
#   inflating: train/1229.jpg
#   inflating: train/123.jpg
#   inflating: train/1230.jpg
#   inflating: train/1231.jpg
#   inflating: train/1232.jpg
#   inflating: train/1233.jpg
#   inflating: train/1234.jpg
#   inflating: train/1235.jpg
#   inflating: train/1236.jpg
#   inflating: train/1237.jpg
#   inflating: train/1238.jpg
#   inflating: train/1239.jpg
#   inflating: train/124.jpg
#   inflating: train/1240.jpg
#   inflating: train/1241.jpg
#   inflating: train/1242.jpg
#   inflating: train/1243.jpg
#   inflating: train/1244.jpg
#   inflating: train/1245.jpg
#   inflating: train/1246.jpg
#   inflating: train/1247.jpg
#   inflating: train/1248.jpg
#   inflating: train/1249.jpg
#   inflating: train/125.jpg
#   inflating: train/1250.jpg
#   inflating: train/1251.jpg
#   inflating: train/1252.jpg
#   inflating: train/1253.jpg
#   inflating: train/1254.jpg
#   inflating: train/1255.jpg
#   inflating: train/1256.jpg
#   inflating: train/1257.jpg
#   inflating: train/1258.jpg
#   inflating: train/1259.jpg
#   inflating: train/126.jpg
#   inflating: train/1260.jpg
#   inflating: train/1261.jpg
#   inflating: train/1262.jpg
#   inflating: train/1263.jpg
#   inflating: train/1264.jpg
#   inflating: train/1265.jpg
#   inflating: train/1266.jpg
#   inflating: train/1267.jpg
#   inflating: train/1268.jpg
#   inflating: train/1269.jpg
#   inflating: train/127.jpg
#   inflating: train/1270.jpg
#   inflating: train/1271.jpg
#   inflating: train/1272.jpg
#   inflating: train/1273.jpg
#   inflating: train/1274.jpg
#   inflating: train/1275.jpg
#   inflating: train/1276.jpg
#   inflating: train/1277.jpg
#   inflating: train/1278.jpg
#   inflating: train/1279.jpg
#   inflating: train/128.jpg
#   inflating: train/1280.jpg
#   inflating: train/1281.jpg
#   inflating: train/1282.jpg
#   inflating: train/1283.jpg
#   inflating: train/1284.jpg
#   inflating: train/1285.jpg
#   inflating: train/1286.jpg
#   inflating: train/1287.jpg
#   inflating: train/1288.jpg
#   inflating: train/1289.jpg
#   inflating: train/129.jpg
#   inflating: train/1290.jpg
#   inflating: train/1291.jpg
#   inflating: train/1292.jpg
#   inflating: train/1293.jpg
#   inflating: train/1294.jpg
#   inflating: train/1295.jpg
#   inflating: train/1296.jpg
#   inflating: train/1297.jpg
#   inflating: train/1298.jpg
#   inflating: train/1299.jpg
#   inflating: train/13.jpg
#   inflating: train/130.jpg
#   inflating: train/1300.jpg
#   inflating: train/1301.jpg
#   inflating: train/1302.jpg
#   inflating: train/1303.jpg
#   inflating: train/1304.jpg
#   inflating: train/1305.jpg
#   inflating: train/1306.jpg
#   inflating: train/1307.jpg
#   inflating: train/1308.jpg
#   inflating: train/1309.jpg
#   inflating: train/131.jpg
#   inflating: train/1310.jpg
#   inflating: train/1311.jpg
#   inflating: train/1312.jpg
#   inflating: train/1313.jpg
#   inflating: train/1314.jpg
#   inflating: train/1315.jpg
#   inflating: train/1316.jpg
#   inflating: train/1317.jpg
#   inflating: train/1318.jpg
#   inflating: train/1319.jpg
#   inflating: train/132.jpg
#   inflating: train/1320.jpg
#   inflating: train/1321.jpg
#   inflating: train/1322.jpg
#   inflating: train/1323.jpg
#   inflating: train/1324.jpg
#   inflating: train/1325.jpg
#   inflating: train/1326.jpg
#   inflating: train/1327.jpg
#   inflating: train/1328.jpg
#   inflating: train/1329.jpg
#   inflating: train/133.jpg
#   inflating: train/1330.jpg
#   inflating: train/1331.jpg
#   inflating: train/1332.jpg
#   inflating: train/1333.jpg
#   inflating: train/1334.jpg
#   inflating: train/1335.jpg
#   inflating: train/1336.jpg
#   inflating: train/1337.jpg
#   inflating: train/1338.jpg
#   inflating: train/1339.jpg
#   inflating: train/134.jpg
#   inflating: train/1340.jpg
#   inflating: train/1341.jpg
#   inflating: train/1342.jpg
#   inflating: train/1343.jpg
#   inflating: train/1344.jpg
#   inflating: train/1345.jpg
#   inflating: train/1346.jpg
#   inflating: train/1347.jpg
#   inflating: train/1348.jpg
#   inflating: train/1349.jpg
#   inflating: train/135.jpg
#   inflating: train/1350.jpg
#   inflating: train/1351.jpg
#   inflating: train/1352.jpg
#   inflating: train/1353.jpg
#   inflating: train/1354.jpg
#   inflating: train/1355.jpg
#   inflating: train/1356.jpg
#   inflating: train/1357.jpg
#   inflating: train/1358.jpg
#   inflating: train/1359.jpg
#   inflating: train/136.jpg
#   inflating: train/1360.jpg
#   inflating: train/1361.jpg
#   inflating: train/1362.jpg
#   inflating: train/1363.jpg
#   inflating: train/1364.jpg
#   inflating: train/1365.jpg
#   inflating: train/1366.jpg
#   inflating: train/1367.jpg
#   inflating: train/1368.jpg
#   inflating: train/1369.jpg
#   inflating: train/137.jpg
#   inflating: train/1370.jpg
#   inflating: train/1371.jpg
#   inflating: train/1372.jpg
#   inflating: train/1373.jpg
#   inflating: train/1374.jpg
#   inflating: train/1375.jpg
#   inflating: train/1376.jpg
#   inflating: train/1377.jpg
#   inflating: train/1378.jpg
#   inflating: train/1379.jpg
#   inflating: train/138.jpg
#   inflating: train/1380.jpg
#   inflating: train/1381.jpg
#   inflating: train/1382.jpg
#   inflating: train/1383.jpg
#   inflating: train/1384.jpg
#   inflating: train/1385.jpg
#   inflating: train/1386.jpg
#   inflating: train/1387.jpg
#   inflating: train/1388.jpg
#   inflating: train/1389.jpg
#   inflating: train/139.jpg
#   inflating: train/1390.jpg
#   inflating: train/1391.jpg
#   inflating: train/1392.jpg
#   inflating: train/1393.jpg
#   inflating: train/1394.jpg
#   inflating: train/1395.jpg
#   inflating: train/1396.jpg
#   inflating: train/1397.jpg
#   inflating: train/1398.jpg
#   inflating: train/1399.jpg
#   inflating: train/14.jpg
#   inflating: train/140.jpg
#   inflating: train/1400.jpg
#   inflating: train/1401.jpg
#   inflating: train/1402.jpg
#   inflating: train/1403.jpg
#   inflating: train/1404.jpg
#   inflating: train/1405.jpg
#   inflating: train/1406.jpg
#   inflating: train/1407.jpg
#   inflating: train/1408.jpg
#   inflating: train/1409.jpg
#   inflating: train/141.jpg
#   inflating: train/1410.jpg
#   inflating: train/1411.jpg
#   inflating: train/1412.jpg
#   inflating: train/1413.jpg
#   inflating: train/1414.jpg
#   inflating: train/1415.jpg
#   inflating: train/1416.jpg
#   inflating: train/1417.jpg
#   inflating: train/1418.jpg
#   inflating: train/1419.jpg
#   inflating: train/142.jpg
#   inflating: train/1420.jpg
#   inflating: train/1421.jpg
#   inflating: train/1422.jpg
#   inflating: train/1423.jpg
#   inflating: train/1424.jpg
#   inflating: train/1425.jpg
#   inflating: train/1426.jpg
#   inflating: train/1427.jpg
#   inflating: train/1428.jpg
#   inflating: train/1429.jpg
#   inflating: train/143.jpg
#   inflating: train/1430.jpg
#   inflating: train/1431.jpg
#   inflating: train/1432.jpg
#   inflating: train/1433.jpg
#   inflating: train/1434.jpg
#   inflating: train/1435.jpg
#   inflating: train/1436.jpg
#   inflating: train/1437.jpg
#   inflating: train/1438.jpg
#   inflating: train/1439.jpg
#   inflating: train/144.jpg
#   inflating: train/1440.jpg
#   inflating: train/1441.jpg
#   inflating: train/1442.jpg
#   inflating: train/1443.jpg
#   inflating: train/1444.jpg
#   inflating: train/1445.jpg
#   inflating: train/1446.jpg
#   inflating: train/1447.jpg
#   inflating: train/1448.jpg
#   inflating: train/1449.jpg
#   inflating: train/145.jpg
#   inflating: train/1450.jpg
#   inflating: train/1451.jpg
#   inflating: train/1452.jpg
#   inflating: train/1453.jpg
#   inflating: train/1454.jpg
#   inflating: train/1455.jpg
#   inflating: train/1456.jpg
#   inflating: train/1457.jpg
#   inflating: train/1458.jpg
#   inflating: train/1459.jpg
#   inflating: train/146.jpg
#   inflating: train/1460.jpg
#   inflating: train/1461.jpg
#   inflating: train/1462.jpg
#   inflating: train/1463.jpg
#   inflating: train/1464.jpg
#   inflating: train/1465.jpg
#   inflating: train/1466.jpg
#   inflating: train/1467.jpg
#   inflating: train/1468.jpg
#   inflating: train/1469.jpg
#   inflating: train/147.jpg
#   inflating: train/1470.jpg
#   inflating: train/1471.jpg
#   inflating: train/1472.jpg
#   inflating: train/1473.jpg
#   inflating: train/1474.jpg
#   inflating: train/1475.jpg
#   inflating: train/1476.jpg
#   inflating: train/1477.jpg
#   inflating: train/1478.jpg
#   inflating: train/1479.jpg
#   inflating: train/148.jpg
#   inflating: train/1480.jpg
#   inflating: train/1481.jpg
#   inflating: train/1482.jpg
#   inflating: train/1483.jpg
#   inflating: train/1484.jpg
#   inflating: train/1485.jpg
#   inflating: train/1486.jpg
#   inflating: train/1487.jpg
#   inflating: train/1488.jpg
#   inflating: train/1489.jpg
#   inflating: train/149.jpg
#   inflating: train/1490.jpg
#   inflating: train/1491.jpg
#   inflating: train/1492.jpg
#   inflating: train/1493.jpg
#   inflating: train/1494.jpg
#   inflating: train/1495.jpg
#   inflating: train/1496.jpg
#   inflating: train/1497.jpg
#   inflating: train/1498.jpg
#   inflating: train/1499.jpg
#   inflating: train/15.jpg
#   inflating: train/150.jpg
#   inflating: train/1500.jpg
#   inflating: train/1501.jpg
#   inflating: train/1502.jpg
#   inflating: train/1503.jpg
#   inflating: train/1504.jpg
#   inflating: train/1505.jpg
#   inflating: train/1506.jpg
#   inflating: train/1507.jpg
#   inflating: train/1508.jpg
#   inflating: train/1509.jpg
#   inflating: train/151.jpg
#   inflating: train/1510.jpg
#   inflating: train/1511.jpg
#   inflating: train/1512.jpg
#   inflating: train/1513.jpg
#   inflating: train/1514.jpg
#   inflating: train/1515.jpg
#   inflating: train/1516.jpg
#   inflating: train/1517.jpg
#   inflating: train/1518.jpg
#   inflating: train/1519.jpg
#   inflating: train/152.jpg
#   inflating: train/1520.jpg
#   inflating: train/1521.jpg
#   inflating: train/1522.jpg
#   inflating: train/1523.jpg
#   inflating: train/1524.jpg
#   inflating: train/1525.jpg
#   inflating: train/1526.jpg
#   inflating: train/1527.jpg
#   inflating: train/1528.jpg
#   inflating: train/1529.jpg
#   inflating: train/153.jpg
#   inflating: train/1530.jpg
#   inflating: train/1531.jpg
#   inflating: train/1532.jpg
#   inflating: train/1533.jpg
#   inflating: train/1534.jpg
#   inflating: train/1535.jpg
#   inflating: train/1536.jpg
#   inflating: train/1537.jpg
#   inflating: train/1538.jpg
#   inflating: train/1539.jpg
#   inflating: train/154.jpg
#   inflating: train/1540.jpg
#   inflating: train/1541.jpg
#   inflating: train/1542.jpg
#   inflating: train/1543.jpg
#   inflating: train/1544.jpg
#   inflating: train/1545.jpg
#   inflating: train/1546.jpg
#   inflating: train/1547.jpg
#   inflating: train/1548.jpg
#   inflating: train/1549.jpg
#   inflating: train/155.jpg
#   inflating: train/1550.jpg
#   inflating: train/1551.jpg
#   inflating: train/1552.jpg
#   inflating: train/1553.jpg
#   inflating: train/1554.jpg
#   inflating: train/1555.jpg
#   inflating: train/1556.jpg
#   inflating: train/1557.jpg
#   inflating: train/1558.jpg
#   inflating: train/1559.jpg
#   inflating: train/156.jpg
#   inflating: train/1560.jpg
#   inflating: train/1561.jpg
#   inflating: train/1562.jpg
#   inflating: train/1563.jpg
#   inflating: train/1564.jpg
#   inflating: train/1565.jpg
#   inflating: train/1566.jpg
#   inflating: train/1567.jpg
#   inflating: train/1568.jpg
#   inflating: train/1569.jpg
#   inflating: train/157.jpg
#   inflating: train/1570.jpg
#   inflating: train/1571.jpg
#   inflating: train/1572.jpg
#   inflating: train/1573.jpg
#   inflating: train/1574.jpg
#   inflating: train/1575.jpg
#   inflating: train/1576.jpg
#   inflating: train/1577.jpg
#   inflating: train/1578.jpg
#   inflating: train/1579.jpg
#   inflating: train/158.jpg
#   inflating: train/1580.jpg
#   inflating: train/1581.jpg
#   inflating: train/1582.jpg
#   inflating: train/1583.jpg
#   inflating: train/1584.jpg
#   inflating: train/1585.jpg
#   inflating: train/1586.jpg
#   inflating: train/1587.jpg
#   inflating: train/1588.jpg
#   inflating: train/1589.jpg
#   inflating: train/159.jpg
#   inflating: train/1590.jpg
#   inflating: train/1591.jpg
#   inflating: train/1592.jpg
#   inflating: train/1593.jpg
#   inflating: train/1594.jpg
#   inflating: train/1595.jpg
#   inflating: train/1596.jpg
#   inflating: train/1597.jpg
#   inflating: train/1598.jpg
#   inflating: train/1599.jpg
#   inflating: train/16.jpg
#   inflating: train/160.jpg
#   inflating: train/1600.jpg
#   inflating: train/1601.jpg
#   inflating: train/1602.jpg
#   inflating: train/1603.jpg
#   inflating: train/1604.jpg
#   inflating: train/1605.jpg
#   inflating: train/1606.jpg
#   inflating: train/1607.jpg
#   inflating: train/1608.jpg
#   inflating: train/1609.jpg
#   inflating: train/161.jpg
#   inflating: train/1610.jpg
#   inflating: train/1611.jpg
#   inflating: train/1612.jpg
#   inflating: train/1613.jpg
#   inflating: train/1614.jpg
#   inflating: train/1615.jpg
#   inflating: train/1616.jpg
#   inflating: train/1617.jpg
#   inflating: train/1618.jpg
#   inflating: train/1619.jpg
#   inflating: train/162.jpg
#   inflating: train/1620.jpg
#   inflating: train/1621.jpg
#   inflating: train/1622.jpg
#   inflating: train/1623.jpg
#   inflating: train/1624.jpg
#   inflating: train/1625.jpg
#   inflating: train/1626.jpg
#   inflating: train/1627.jpg
#   inflating: train/1628.jpg
#   inflating: train/1629.jpg
#   inflating: train/163.jpg
#   inflating: train/1630.jpg
#   inflating: train/1631.jpg
#   inflating: train/1632.jpg
#   inflating: train/1633.jpg
#   inflating: train/1634.jpg
#   inflating: train/1635.jpg
#   inflating: train/1636.jpg
#   inflating: train/1637.jpg
#   inflating: train/1638.jpg
#   inflating: train/1639.jpg
#   inflating: train/164.jpg
#   inflating: train/1640.jpg
#   inflating: train/1641.jpg
#   inflating: train/1642.jpg
#   inflating: train/1643.jpg
#   inflating: train/1644.jpg
#   inflating: train/1645.jpg
#   inflating: train/1646.jpg
#   inflating: train/1647.jpg
#   inflating: train/1648.jpg
#   inflating: train/1649.jpg
#   inflating: train/165.jpg
#   inflating: train/1650.jpg
#   inflating: train/1651.jpg
#   inflating: train/1652.jpg
#   inflating: train/1653.jpg
#   inflating: train/1654.jpg
#   inflating: train/1655.jpg
#   inflating: train/1656.jpg
#   inflating: train/1657.jpg
#   inflating: train/1658.jpg
#   inflating: train/1659.jpg
#   inflating: train/166.jpg
#   inflating: train/1660.jpg
#   inflating: train/1661.jpg
#   inflating: train/1662.jpg
#   inflating: train/1663.jpg
#   inflating: train/1664.jpg
#   inflating: train/1665.jpg
#   inflating: train/1666.jpg
#   inflating: train/1667.jpg
#   inflating: train/1668.jpg
#   inflating: train/1669.jpg
#   inflating: train/167.jpg
#   inflating: train/1670.jpg
#   inflating: train/1671.jpg
#   inflating: train/1672.jpg
#   inflating: train/1673.jpg
#   inflating: train/1674.jpg
#   inflating: train/1675.jpg
#   inflating: train/1676.jpg
#   inflating: train/1677.jpg
#   inflating: train/1678.jpg
#   inflating: train/1679.jpg
#   inflating: train/168.jpg
#   inflating: train/1680.jpg
#   inflating: train/1681.jpg
#   inflating: train/1682.jpg
#   inflating: train/1683.jpg
#   inflating: train/1684.jpg
#   inflating: train/1685.jpg
#   inflating: train/1686.jpg
#   inflating: train/1687.jpg
#   inflating: train/1688.jpg
#   inflating: train/1689.jpg
#   inflating: train/169.jpg
#   inflating: train/1690.jpg
#   inflating: train/1691.jpg
#   inflating: train/1692.jpg
#   inflating: train/1693.jpg
#   inflating: train/1694.jpg
#   inflating: train/1695.jpg
#   inflating: train/1696.jpg
#   inflating: train/1697.jpg
#   inflating: train/1698.jpg
#   inflating: train/1699.jpg
#   inflating: train/17.jpg
#   inflating: train/170.jpg
#   inflating: train/1700.jpg
#   inflating: train/1701.jpg
#   inflating: train/1702.jpg
#   inflating: train/1703.jpg
#   inflating: train/1704.jpg
#   inflating: train/1705.jpg
#   inflating: train/1706.jpg
#   inflating: train/1707.jpg
#   inflating: train/1708.jpg
#   inflating: train/1709.jpg
#   inflating: train/171.jpg
#   inflating: train/1710.jpg
#   inflating: train/1711.jpg
#   inflating: train/1712.jpg
#   inflating: train/1713.jpg
#   inflating: train/1714.jpg
#   inflating: train/1715.jpg
#   inflating: train/1716.jpg
#   inflating: train/1717.jpg
#   inflating: train/1718.jpg
#   inflating: train/1719.jpg
#   inflating: train/172.jpg
#   inflating: train/1720.jpg
#   inflating: train/1721.jpg
#   inflating: train/1722.jpg
#   inflating: train/1723.jpg
#   inflating: train/1724.jpg
#   inflating: train/1725.jpg
#   inflating: train/1726.jpg
#   inflating: train/1727.jpg
#   inflating: train/1728.jpg
#   inflating: train/1729.jpg
#   inflating: train/173.jpg
#   inflating: train/1730.jpg
#   inflating: train/1731.jpg
#   inflating: train/1732.jpg
#   inflating: train/1733.jpg
#   inflating: train/1734.jpg
#   inflating: train/1735.jpg
#   inflating: train/1736.jpg
#   inflating: train/1737.jpg
#   inflating: train/1738.jpg
#   inflating: train/1739.jpg
#   inflating: train/174.jpg
#   inflating: train/1740.jpg
#   inflating: train/1741.jpg
#   inflating: train/1742.jpg
#   inflating: train/1743.jpg
#   inflating: train/1744.jpg
#   inflating: train/1745.jpg
#   inflating: train/1746.jpg
#   inflating: train/1747.jpg
#   inflating: train/1748.jpg
#   inflating: train/1749.jpg
#   inflating: train/175.jpg
#   inflating: train/1750.jpg
#   inflating: train/1751.jpg
#   inflating: train/1752.jpg
#   inflating: train/1753.jpg
#   inflating: train/1754.jpg
#   inflating: train/1755.jpg
#   inflating: train/1756.jpg
#   inflating: train/1757.jpg
#   inflating: train/1758.jpg
#   inflating: train/1759.jpg
#   inflating: train/176.jpg
#   inflating: train/1760.jpg
#   inflating: train/1761.jpg
#   inflating: train/1762.jpg
#   inflating: train/1763.jpg
#   inflating: train/1764.jpg
#   inflating: train/1765.jpg
#   inflating: train/1766.jpg
#   inflating: train/1767.jpg
#   inflating: train/1768.jpg
#   inflating: train/1769.jpg
#   inflating: train/177.jpg
#   inflating: train/1770.jpg
#   inflating: train/1771.jpg
#   inflating: train/1772.jpg
#   inflating: train/1773.jpg
#   inflating: train/1774.jpg
#   inflating: train/1775.jpg
#   inflating: train/1776.jpg
#   inflating: train/1777.jpg
#   inflating: train/1778.jpg
#   inflating: train/1779.jpg
#   inflating: train/178.jpg
#   inflating: train/1780.jpg
#   inflating: train/1781.jpg
#   inflating: train/1782.jpg
#   inflating: train/1783.jpg
#   inflating: train/1784.jpg
#   inflating: train/1785.jpg
#   inflating: train/1786.jpg
#   inflating: train/1787.jpg
#   inflating: train/1788.jpg
#   inflating: train/1789.jpg
#   inflating: train/179.jpg
#   inflating: train/1790.jpg
#   inflating: train/1791.jpg
#   inflating: train/1792.jpg
#   inflating: train/1793.jpg
#   inflating: train/1794.jpg
#   inflating: train/1795.jpg
#   inflating: train/1796.jpg
#   inflating: train/1797.jpg
#   inflating: train/1798.jpg
#   inflating: train/1799.jpg
#   inflating: train/18.jpg
#   inflating: train/180.jpg
#   inflating: train/1800.jpg
#   inflating: train/1801.jpg
#   inflating: train/1802.jpg
#   inflating: train/1803.jpg
#   inflating: train/1804.jpg
#   inflating: train/1805.jpg
#   inflating: train/1806.jpg
#   inflating: train/1807.jpg
#   inflating: train/1808.jpg
#   inflating: train/1809.jpg
#   inflating: train/181.jpg
#   inflating: train/1810.jpg
#   inflating: train/1811.jpg
#   inflating: train/1812.jpg
#   inflating: train/1813.jpg
#   inflating: train/1814.jpg
#   inflating: train/1815.jpg
#   inflating: train/1816.jpg
#   inflating: train/1817.jpg
#   inflating: train/1818.jpg
#   inflating: train/1819.jpg
#   inflating: train/182.jpg
#   inflating: train/1820.jpg
#   inflating: train/1821.jpg
#   inflating: train/1822.jpg
#   inflating: train/1823.jpg
#   inflating: train/1824.jpg
#   inflating: train/1825.jpg
#   inflating: train/1826.jpg
#   inflating: train/1827.jpg
#   inflating: train/1828.jpg
#   inflating: train/1829.jpg
#   inflating: train/183.jpg
#   inflating: train/1830.jpg
#   inflating: train/1831.jpg
#   inflating: train/1832.jpg
#   inflating: train/1833.jpg
#   inflating: train/1834.jpg
#   inflating: train/1835.jpg
#   inflating: train/1836.jpg
#   inflating: train/1837.jpg
#   inflating: train/1838.jpg
#   inflating: train/1839.jpg
#   inflating: train/184.jpg
#   inflating: train/1840.jpg
#   inflating: train/1841.jpg
#   inflating: train/1842.jpg
#   inflating: train/1843.jpg
#   inflating: train/1844.jpg
#   inflating: train/1845.jpg
#   inflating: train/1846.jpg
#   inflating: train/1847.jpg
#   inflating: train/1848.jpg
#   inflating: train/1849.jpg
#   inflating: train/185.jpg
#   inflating: train/1850.jpg
#   inflating: train/1851.jpg
#   inflating: train/1852.jpg
#   inflating: train/1853.jpg
#   inflating: train/1854.jpg
#   inflating: train/1855.jpg
#   inflating: train/1856.jpg
#   inflating: train/1857.jpg
#   inflating: train/1858.jpg
#   inflating: train/1859.jpg
#   inflating: train/186.jpg
#   inflating: train/1860.jpg
#   inflating: train/1861.jpg
#   inflating: train/1862.jpg
#   inflating: train/1863.jpg
#   inflating: train/1864.jpg
#   inflating: train/1865.jpg
#   inflating: train/1866.jpg
#   inflating: train/1867.jpg
#   inflating: train/1868.jpg
#   inflating: train/1869.jpg
#   inflating: train/187.jpg
#   inflating: train/1870.jpg
#   inflating: train/1871.jpg
#   inflating: train/1872.jpg
#   inflating: train/1873.jpg
#   inflating: train/1874.jpg
#   inflating: train/1875.jpg
#   inflating: train/1876.jpg
#   inflating: train/1877.jpg
#   inflating: train/1878.jpg
#   inflating: train/1879.jpg
#   inflating: train/188.jpg
#   inflating: train/1880.jpg
#   inflating: train/1881.jpg
#   inflating: train/1882.jpg
#   inflating: train/1883.jpg
#   inflating: train/1884.jpg
#   inflating: train/1885.jpg
#   inflating: train/1886.jpg
#   inflating: train/1887.jpg
#   inflating: train/1888.jpg
#   inflating: train/1889.jpg
#   inflating: train/189.jpg
#   inflating: train/1890.jpg
#   inflating: train/1891.jpg
#   inflating: train/1892.jpg
#   inflating: train/1893.jpg
#   inflating: train/1894.jpg
#   inflating: train/1895.jpg
#   inflating: train/1896.jpg
#   inflating: train/1897.jpg
#   inflating: train/1898.jpg
#   inflating: train/1899.jpg
#   inflating: train/19.jpg
#   inflating: train/190.jpg
#   inflating: train/1900.jpg
#   inflating: train/1901.jpg
#   inflating: train/1902.jpg
#   inflating: train/1903.jpg
#   inflating: train/1904.jpg
#   inflating: train/1905.jpg
#   inflating: train/1906.jpg
#   inflating: train/1907.jpg
#   inflating: train/1908.jpg
#   inflating: train/1909.jpg
#   inflating: train/191.jpg
#   inflating: train/1910.jpg
#   inflating: train/1911.jpg
#   inflating: train/1912.jpg
#   inflating: train/1913.jpg
#   inflating: train/1914.jpg
#   inflating: train/1915.jpg
#   inflating: train/1916.jpg
#   inflating: train/1917.jpg
#   inflating: train/1918.jpg
#   inflating: train/1919.jpg
#   inflating: train/192.jpg
#   inflating: train/1920.jpg
#   inflating: train/1921.jpg
#   inflating: train/1922.jpg
#   inflating: train/1923.jpg
#   inflating: train/1924.jpg
#   inflating: train/1925.jpg
#   inflating: train/1926.jpg
#   inflating: train/1927.jpg
#   inflating: train/1928.jpg
#   inflating: train/1929.jpg
#   inflating: train/193.jpg
#   inflating: train/1930.jpg
#   inflating: train/1931.jpg
#   inflating: train/1932.jpg
#   inflating: train/1933.jpg
#   inflating: train/1934.jpg
#   inflating: train/1935.jpg
#   inflating: train/1936.jpg
#   inflating: train/1937.jpg
#   inflating: train/1938.jpg
#   inflating: train/1939.jpg
#   inflating: train/194.jpg
#   inflating: train/1940.jpg
#   inflating: train/1941.jpg
#   inflating: train/1942.jpg
#   inflating: train/1943.jpg
#   inflating: train/1944.jpg
#   inflating: train/1945.jpg
#   inflating: train/1946.jpg
#   inflating: train/1947.jpg
#   inflating: train/1948.jpg
#   inflating: train/1949.jpg
#   inflating: train/195.jpg
#   inflating: train/1950.jpg
#   inflating: train/1951.jpg
#   inflating: train/1952.jpg
#   inflating: train/1953.jpg
#   inflating: train/1954.jpg
#   inflating: train/1955.jpg
#   inflating: train/1956.jpg
#   inflating: train/1957.jpg
#   inflating: train/1958.jpg
#   inflating: train/1959.jpg
#   inflating: train/196.jpg
#   inflating: train/1960.jpg
#   inflating: train/1961.jpg
#   inflating: train/1962.jpg
#   inflating: train/1963.jpg
#   inflating: train/1964.jpg
#   inflating: train/1965.jpg
#   inflating: train/1966.jpg
#   inflating: train/1967.jpg
#   inflating: train/1968.jpg
#   inflating: train/1969.jpg
#   inflating: train/197.jpg
#   inflating: train/1970.jpg
#   inflating: train/1971.jpg
#   inflating: train/1972.jpg
#   inflating: train/1973.jpg
#   inflating: train/1974.jpg
#   inflating: train/1975.jpg
#   inflating: train/1976.jpg
#   inflating: train/1977.jpg
#   inflating: train/1978.jpg
#   inflating: train/1979.jpg
#   inflating: train/198.jpg
#   inflating: train/1980.jpg
#   inflating: train/1981.jpg
#   inflating: train/1982.jpg
#   inflating: train/1983.jpg
#   inflating: train/1984.jpg
#   inflating: train/1985.jpg
#   inflating: train/1986.jpg
#   inflating: train/1987.jpg
#   inflating: train/1988.jpg
#   inflating: train/1989.jpg
#   inflating: train/199.jpg
#   inflating: train/1990.jpg
#   inflating: train/1991.jpg
#   inflating: train/1992.jpg
#   inflating: train/1993.jpg
#   inflating: train/1994.jpg
#   inflating: train/1995.jpg
#   inflating: train/1996.jpg
#   inflating: train/1997.jpg
#   inflating: train/1998.jpg
#   inflating: train/1999.jpg
#   inflating: train/2.jpg
#   inflating: train/20.jpg
#   inflating: train/200.jpg
#   inflating: train/2000.jpg
#   inflating: train/2001.jpg
#   inflating: train/2002.jpg
#   inflating: train/2003.jpg
#   inflating: train/2004.jpg
#   inflating: train/2005.jpg
#   inflating: train/2006.jpg
#   inflating: train/2007.jpg
#   inflating: train/2008.jpg
#   inflating: train/2009.jpg
#   inflating: train/201.jpg
#   inflating: train/2010.jpg
#   inflating: train/2011.jpg
#   inflating: train/2012.jpg
#   inflating: train/2013.jpg
#   inflating: train/2014.jpg
#   inflating: train/2015.jpg
#   inflating: train/2016.jpg
#   inflating: train/2017.jpg
#   inflating: train/2018.jpg
#   inflating: train/2019.jpg
#   inflating: train/202.jpg
#   inflating: train/2020.jpg
#   inflating: train/2021.jpg
#   inflating: train/2022.jpg
#   inflating: train/2023.jpg
#   inflating: train/2024.jpg
#   inflating: train/2025.jpg
#   inflating: train/2026.jpg
#   inflating: train/2027.jpg
#   inflating: train/2028.jpg
#   inflating: train/2029.jpg
#   inflating: train/203.jpg
#   inflating: train/2030.jpg
#   inflating: train/2031.jpg
#   inflating: train/2032.jpg
#   inflating: train/2033.jpg
#   inflating: train/2034.jpg
#   inflating: train/2035.jpg
#   inflating: train/2036.jpg
#   inflating: train/2037.jpg
#   inflating: train/2038.jpg
#   inflating: train/2039.jpg
#   inflating: train/204.jpg
#   inflating: train/2040.jpg
#   inflating: train/2041.jpg
#   inflating: train/2042.jpg
#   inflating: train/2043.jpg
#   inflating: train/2044.jpg
#   inflating: train/2045.jpg
#   inflating: train/2046.jpg
#   inflating: train/2047.jpg
#   inflating: train/2048.jpg
#   inflating: train/2049.jpg
#   inflating: train/205.jpg
#   inflating: train/2050.jpg
#   inflating: train/2051.jpg
#   inflating: train/2052.jpg
#   inflating: train/2053.jpg
#   inflating: train/2054.jpg
#   inflating: train/2055.jpg
#   inflating: train/2056.jpg
#   inflating: train/2057.jpg
#   inflating: train/2058.jpg
#   inflating: train/2059.jpg
#   inflating: train/206.jpg
#   inflating: train/2060.jpg
#   inflating: train/2061.jpg
#   inflating: train/2062.jpg
#   inflating: train/2063.jpg
#   inflating: train/2064.jpg
#   inflating: train/2065.jpg
#   inflating: train/2066.jpg
#   inflating: train/2067.jpg
#   inflating: train/2068.jpg
#   inflating: train/2069.jpg
#   inflating: train/207.jpg
#   inflating: train/2070.jpg
#   inflating: train/2071.jpg
#   inflating: train/2072.jpg
#   inflating: train/2073.jpg
#   inflating: train/2074.jpg
#   inflating: train/2075.jpg
#   inflating: train/2076.jpg
#   inflating: train/2077.jpg
#   inflating: train/2078.jpg
#   inflating: train/2079.jpg
#   inflating: train/208.jpg
#   inflating: train/2080.jpg
#   inflating: train/2081.jpg
#   inflating: train/2082.jpg
#   inflating: train/2083.jpg
#   inflating: train/2084.jpg
#   inflating: train/2085.jpg
#   inflating: train/2086.jpg
#   inflating: train/2087.jpg
#   inflating: train/2088.jpg
#   inflating: train/2089.jpg
#   inflating: train/209.jpg
#   inflating: train/2090.jpg
#   inflating: train/2091.jpg
#   inflating: train/2092.jpg
#   inflating: train/2093.jpg
#   inflating: train/2094.jpg
#   inflating: train/2095.jpg
#   inflating: train/2096.jpg
#   inflating: train/2097.jpg
#   inflating: train/2098.jpg
#   inflating: train/2099.jpg
#   inflating: train/21.jpg
#   inflating: train/210.jpg
#   inflating: train/2100.jpg
#   inflating: train/2101.jpg
#   inflating: train/2102.jpg
#   inflating: train/2103.jpg
#   inflating: train/2104.jpg
#   inflating: train/2105.jpg
#   inflating: train/2106.jpg
#   inflating: train/2107.jpg
#   inflating: train/2108.jpg
#   inflating: train/2109.jpg
#   inflating: train/211.jpg
#   inflating: train/2110.jpg
#   inflating: train/2111.jpg
#   inflating: train/2112.jpg
#   inflating: train/2113.jpg
#   inflating: train/2114.jpg
#   inflating: train/2115.jpg
#   inflating: train/2116.jpg
#   inflating: train/2117.jpg
#   inflating: train/2118.jpg
#   inflating: train/2119.jpg
#   inflating: train/212.jpg
#   inflating: train/2120.jpg
#   inflating: train/2121.jpg
#   inflating: train/2122.jpg
#   inflating: train/2123.jpg
#   inflating: train/2124.jpg
#   inflating: train/2125.jpg
#   inflating: train/2126.jpg
#   inflating: train/2127.jpg
#   inflating: train/2128.jpg
#   inflating: train/2129.jpg
#   inflating: train/213.jpg
#   inflating: train/2130.jpg
#   inflating: train/2131.jpg
#   inflating: train/2132.jpg
#   inflating: train/2133.jpg
# ...
#   inflating: val/170.jpg
#   inflating: val/171.jpg
#   inflating: val/172.jpg
#   inflating: val/173.jpg
#   inflating: val/174.jpg
#   inflating: val/175.jpg
#   inflating: val/176.jpg
#   inflating: val/177.jpg
#   inflating: val/178.jpg
#   inflating: val/179.jpg
#   inflating: val/18.jpg
#   inflating: val/180.jpg
#   inflating: val/181.jpg
#   inflating: val/182.jpg
#   inflating: val/183.jpg
#   inflating: val/184.jpg
#   inflating: val/185.jpg
#   inflating: val/186.jpg
#   inflating: val/187.jpg
#   inflating: val/188.jpg
#   inflating: val/189.jpg
#   inflating: val/19.jpg
#   inflating: val/190.jpg
#   inflating: val/191.jpg
#   inflating: val/192.jpg
#   inflating: val/193.jpg
#   inflating: val/194.jpg
#   inflating: val/195.jpg
#   inflating: val/196.jpg
#   inflating: val/197.jpg
#   inflating: val/198.jpg
#   inflating: val/199.jpg
#   inflating: val/2.jpg
#   inflating: val/20.jpg
#   inflating: val/200.jpg
#   inflating: val/201.jpg
#   inflating: val/202.jpg
#   inflating: val/203.jpg
#   inflating: val/204.jpg
#   inflating: val/205.jpg
#   inflating: val/206.jpg
#   inflating: val/207.jpg
#   inflating: val/208.jpg
#   inflating: val/209.jpg
#   inflating: val/21.jpg
#   inflating: val/210.jpg
#   inflating: val/211.jpg
#   inflating: val/212.jpg
#   inflating: val/213.jpg
#   inflating: val/214.jpg
#   inflating: val/215.jpg
#   inflating: val/216.jpg
#   inflating: val/217.jpg
#   inflating: val/218.jpg
#   inflating: val/219.jpg
#   inflating: val/22.jpg
#   inflating: val/220.jpg
#   inflating: val/221.jpg
#   inflating: val/222.jpg
#   inflating: val/223.jpg
#   inflating: val/224.jpg
#   inflating: val/225.jpg
#   inflating: val/226.jpg
#   inflating: val/227.jpg
#   inflating: val/228.jpg
#   inflating: val/229.jpg
#   inflating: val/23.jpg
#   inflating: val/230.jpg
#   inflating: val/231.jpg
#   inflating: val/232.jpg
#   inflating: val/233.jpg
#   inflating: val/234.jpg
#   inflating: val/235.jpg
#   inflating: val/236.jpg
#   inflating: val/237.jpg
#   inflating: val/238.jpg
#   inflating: val/239.jpg
#   inflating: val/24.jpg
#   inflating: val/240.jpg
#   inflating: val/241.jpg
#   inflating: val/242.jpg
#   inflating: val/243.jpg
#   inflating: val/244.jpg
#   inflating: val/245.jpg
#   inflating: val/246.jpg
#   inflating: val/247.jpg
#   inflating: val/248.jpg
#   inflating: val/249.jpg
#   inflating: val/25.jpg
#   inflating: val/250.jpg
#   inflating: val/251.jpg
#   inflating: val/252.jpg
#   inflating: val/253.jpg
#   inflating: val/254.jpg
#   inflating: val/255.jpg
#   inflating: val/256.jpg
#   inflating: val/257.jpg
#   inflating: val/258.jpg
#   inflating: val/259.jpg
#   inflating: val/26.jpg
#   inflating: val/260.jpg
#   inflating: val/261.jpg
#   inflating: val/262.jpg
#   inflating: val/263.jpg
#   inflating: val/264.jpg
#   inflating: val/265.jpg
#   inflating: val/266.jpg
#   inflating: val/267.jpg
#   inflating: val/268.jpg
#   inflating: val/269.jpg
#   inflating: val/27.jpg
#   inflating: val/270.jpg
#   inflating: val/271.jpg
#   inflating: val/272.jpg
#   inflating: val/273.jpg
#   inflating: val/274.jpg
#   inflating: val/275.jpg
#   inflating: val/276.jpg
#   inflating: val/277.jpg
#   inflating: val/278.jpg
#   inflating: val/279.jpg
#   inflating: val/28.jpg
#   inflating: val/280.jpg
#   inflating: val/281.jpg
#   inflating: val/282.jpg
#   inflating: val/283.jpg
#   inflating: val/284.jpg
#   inflating: val/285.jpg
#   inflating: val/286.jpg
#   inflating: val/287.jpg
#   inflating: val/288.jpg
#   inflating: val/289.jpg
#   inflating: val/29.jpg
#   inflating: val/290.jpg
#   inflating: val/291.jpg
#   inflating: val/292.jpg
#   inflating: val/293.jpg
#   inflating: val/294.jpg
#   inflating: val/295.jpg
#   inflating: val/296.jpg
#   inflating: val/297.jpg
#   inflating: val/298.jpg
#   inflating: val/299.jpg
#   inflating: val/3.jpg
#   inflating: val/30.jpg
#   inflating: val/300.jpg
#   inflating: val/301.jpg
#   inflating: val/302.jpg
#   inflating: val/303.jpg
#   inflating: val/304.jpg
#   inflating: val/305.jpg
#   inflating: val/306.jpg
#   inflating: val/307.jpg
#   inflating: val/308.jpg
#   inflating: val/309.jpg
#   inflating: val/31.jpg
#   inflating: val/310.jpg
#   inflating: val/311.jpg
#   inflating: val/312.jpg
#   inflating: val/313.jpg
#   inflating: val/314.jpg
#   inflating: val/315.jpg
#   inflating: val/316.jpg
#   inflating: val/317.jpg
#   inflating: val/318.jpg
#   inflating: val/319.jpg
#   inflating: val/32.jpg
#   inflating: val/320.jpg
#   inflating: val/321.jpg
#   inflating: val/322.jpg
#   inflating: val/323.jpg
#   inflating: val/324.jpg
#   inflating: val/325.jpg
#   inflating: val/326.jpg
#   inflating: val/327.jpg
#   inflating: val/328.jpg
#   inflating: val/329.jpg
#   inflating: val/33.jpg
#   inflating: val/330.jpg
#   inflating: val/331.jpg
#   inflating: val/332.jpg
#   inflating: val/333.jpg
#   inflating: val/334.jpg
#   inflating: val/335.jpg
#   inflating: val/336.jpg
#   inflating: val/337.jpg
#   inflating: val/338.jpg
#   inflating: val/339.jpg
#   inflating: val/34.jpg
#   inflating: val/340.jpg
#   inflating: val/341.jpg
#   inflating: val/342.jpg
#   inflating: val/343.jpg
#   inflating: val/344.jpg
#   inflating: val/345.jpg
#   inflating: val/346.jpg
#   inflating: val/347.jpg
#   inflating: val/348.jpg
#   inflating: val/349.jpg
#   inflating: val/35.jpg
#   inflating: val/350.jpg
#   inflating: val/351.jpg
#   inflating: val/352.jpg
#   inflating: val/353.jpg
#   inflating: val/354.jpg
#   inflating: val/355.jpg
#   inflating: val/356.jpg
#   inflating: val/357.jpg
#   inflating: val/358.jpg
#   inflating: val/359.jpg
#   inflating: val/36.jpg
#   inflating: val/360.jpg
#   inflating: val/361.jpg
#   inflating: val/362.jpg
#   inflating: val/363.jpg
#   inflating: val/364.jpg
#   inflating: val/365.jpg
#   inflating: val/366.jpg
#   inflating: val/367.jpg
#   inflating: val/368.jpg
#   inflating: val/369.jpg
#   inflating: val/37.jpg
#   inflating: val/370.jpg
#   inflating: val/371.jpg
#   inflating: val/372.jpg
#   inflating: val/373.jpg
#   inflating: val/374.jpg
#   inflating: val/375.jpg
#   inflating: val/376.jpg
#   inflating: val/377.jpg
#   inflating: val/378.jpg
#   inflating: val/379.jpg
#   inflating: val/38.jpg
#   inflating: val/380.jpg
#   inflating: val/381.jpg
#   inflating: val/382.jpg
#   inflating: val/383.jpg
#   inflating: val/384.jpg
#   inflating: val/385.jpg
#   inflating: val/386.jpg
#   inflating: val/387.jpg
#   inflating: val/388.jpg
#   inflating: val/389.jpg
#   inflating: val/39.jpg
#   inflating: val/390.jpg
#   inflating: val/391.jpg
#   inflating: val/392.jpg
#   inflating: val/393.jpg
#   inflating: val/394.jpg
#   inflating: val/395.jpg
#   inflating: val/396.jpg
#   inflating: val/397.jpg
#   inflating: val/398.jpg
#   inflating: val/399.jpg
#   inflating: val/4.jpg
#   inflating: val/40.jpg
#   inflating: val/400.jpg
#   inflating: val/401.jpg
#   inflating: val/402.jpg
#   inflating: val/403.jpg
#   inflating: val/404.jpg
#   inflating: val/405.jpg
#   inflating: val/406.jpg
#   inflating: val/407.jpg
#   inflating: val/408.jpg
#   inflating: val/409.jpg
#   inflating: val/41.jpg
#   inflating: val/410.jpg
#   inflating: val/411.jpg
#   inflating: val/412.jpg
#   inflating: val/413.jpg
#   inflating: val/414.jpg
#   inflating: val/415.jpg
#   inflating: val/416.jpg
#   inflating: val/417.jpg
#   inflating: val/418.jpg
#   inflating: val/419.jpg
#   inflating: val/42.jpg
#   inflating: val/420.jpg
#   inflating: val/421.jpg
#   inflating: val/422.jpg
#   inflating: val/423.jpg
#   inflating: val/424.jpg
#   inflating: val/425.jpg
#   inflating: val/426.jpg
#   inflating: val/427.jpg
#   inflating: val/428.jpg
#   inflating: val/429.jpg
#   inflating: val/43.jpg
#   inflating: val/430.jpg
#   inflating: val/431.jpg
#   inflating: val/432.jpg
#   inflating: val/433.jpg
#   inflating: val/434.jpg
#   inflating: val/435.jpg
#   inflating: val/436.jpg
#   inflating: val/437.jpg
#   inflating: val/438.jpg
#   inflating: val/439.jpg
#   inflating: val/44.jpg
#   inflating: val/440.jpg
#   inflating: val/441.jpg
#   inflating: val/442.jpg
#   inflating: val/443.jpg
#   inflating: val/444.jpg
#   inflating: val/445.jpg
#   inflating: val/446.jpg
#   inflating: val/447.jpg
#   inflating: val/448.jpg
#   inflating: val/449.jpg
#   inflating: val/45.jpg
#   inflating: val/450.jpg
#   inflating: val/451.jpg
#   inflating: val/452.jpg
#   inflating: val/453.jpg
#   inflating: val/454.jpg
#   inflating: val/455.jpg
#   inflating: val/456.jpg
#   inflating: val/457.jpg
#   inflating: val/458.jpg
#   inflating: val/459.jpg
#   inflating: val/46.jpg
#   inflating: val/460.jpg
#   inflating: val/461.jpg
#   inflating: val/462.jpg
#   inflating: val/463.jpg
#   inflating: val/464.jpg
#   inflating: val/465.jpg
#   inflating: val/466.jpg
#   inflating: val/467.jpg
#   inflating: val/468.jpg
#   inflating: val/469.jpg
#   inflating: val/47.jpg
#   inflating: val/470.jpg
#   inflating: val/471.jpg
#   inflating: val/472.jpg
#   inflating: val/473.jpg
#   inflating: val/474.jpg
#   inflating: val/475.jpg
#   inflating: val/476.jpg
#   inflating: val/477.jpg
#   inflating: val/478.jpg
#   inflating: val/479.jpg
#   inflating: val/48.jpg
#   inflating: val/480.jpg
#   inflating: val/481.jpg
#   inflating: val/482.jpg
#   inflating: val/483.jpg
#   inflating: val/484.jpg
#   inflating: val/485.jpg
#   inflating: val/486.jpg
#   inflating: val/487.jpg
#   inflating: val/488.jpg
#   inflating: val/489.jpg
#   inflating: val/49.jpg
#   inflating: val/490.jpg
#   inflating: val/491.jpg
#   inflating: val/492.jpg
#   inflating: val/493.jpg
#   inflating: val/494.jpg
#   inflating: val/495.jpg
#   inflating: val/496.jpg
#   inflating: val/497.jpg
#   inflating: val/498.jpg
#   inflating: val/499.jpg
#   inflating: val/5.jpg
#   inflating: val/50.jpg
#   inflating: val/500.jpg
#   inflating: val/51.jpg
#   inflating: val/52.jpg
#   inflating: val/53.jpg
#   inflating: val/54.jpg
#   inflating: val/55.jpg
#   inflating: val/56.jpg
#   inflating: val/57.jpg
#   inflating: val/58.jpg
#   inflating: val/59.jpg
#   inflating: val/6.jpg
#   inflating: val/60.jpg
#   inflating: val/61.jpg
#   inflating: val/62.jpg
#   inflating: val/63.jpg
#   inflating: val/64.jpg
#   inflating: val/65.jpg
#   inflating: val/66.jpg
#   inflating: val/67.jpg
#   inflating: val/68.jpg
#   inflating: val/69.jpg
#   inflating: val/7.jpg
#   inflating: val/70.jpg
#   inflating: val/71.jpg
#   inflating: val/72.jpg
#   inflating: val/73.jpg
#   inflating: val/74.jpg
#   inflating: val/75.jpg
#   inflating: val/76.jpg
#   inflating: val/77.jpg
#   inflating: val/78.jpg
#   inflating: val/79.jpg
#   inflating: val/8.jpg
#   inflating: val/80.jpg
#   inflating: val/81.jpg
#   inflating: val/82.jpg
#   inflating: val/83.jpg
#   inflating: val/84.jpg
#   inflating: val/85.jpg
#   inflating: val/86.jpg
#   inflating: val/87.jpg
#   inflating: val/88.jpg
#   inflating: val/89.jpg
#   inflating: val/9.jpg
#   inflating: val/90.jpg
#   inflating: val/91.jpg
#   inflating: val/92.jpg
#   inflating: val/93.jpg
#   inflating: val/94.jpg
#   inflating: val/95.jpg
#   inflating: val/96.jpg
#   inflating: val/97.jpg
#   inflating: val/98.jpg
#   inflating: val/99.jpg

# %%
from glob import glob
val_file = glob(f'./val/*')

# %%
from PIL import Image
import os
import torch
import torchvision
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets
from torchvision.utils import save_image
import matplotlib.pyplot as plt
import numpy as np
from torch.utils.data import Dataset, DataLoader

# %%
def tensor_to_image(data):
  return  unnormalize(np.transpose(data.detach().cpu().numpy()[0] , (1, 2, 0)))

# %%
def file_to_PIL(sample):
  
  result = Image.open(sample)

  return result

# %%
def splitTensor(sample):
        C, H, W = sample.shape
        
        input_image = sample[:,:,:int(W/2)]
        target_image = sample[:,:,int(W/2):]
        
        output = torch.cat([input_image,target_image])
        return output

# %%
def make_two_tensor(sample):
  C, H, W = sample.shape   
  input_image = sample[:int(C/2),:,:]
  target_image = sample[int(C/2):,:,:] 

  return input_image, target_image

# %%
def split_input_tensor(sample):
  C, H, W = sample.shape
        
  input_image = sample[:,:,:int(W/2)]
  target_image = sample[:,:,int(W/2):]
  
  output = torch.cat([input_image,target_image])

  return input_image, target_image

# %%
def unnormalize(sample):
  sample = ((sample * 0.5) + 0.5)
  return sample

# %%
def shuffle_batch(data):
  if len(data) == 1:
    return data
  first_data = data[0].clone()
  data[0:-1] = data[1:].clone()
  data[-1] = first_data
  return data

# %%
class CustomDatasest(Dataset):
  def __init__(self, np_data, transform = None):
      self.data = np_data
      self.transform = transform
      self.len = len(np_data)

  def __len__(self):
    return self.len

  def __getitem__(self, idx):
    sample = self.data[idx]
    if self.transform:
      sample = self.transform(sample)
    return sample

# %%
image_height = 256
image_width = 256

# %%
trans = transforms.Compose([
                            file_to_PIL,
                            transforms.ToTensor(),
                            transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5)),
                            transforms.Resize((image_height, image_width*2)),
                            splitTensor,
                            make_two_tensor,
                            ])

# %% [markdown]
# #TMP_loader

# %%
val_dataset = CustomDatasest(val_file, transform = trans)
val_loader = DataLoader(
    dataset = val_dataset, 
    batch_size = 1
)

# %% [markdown]
# #Pix2Pix

# %%
class Pix2pixGenerator(nn.Module):
    def __init__(self, output_nc):
        super(Pix2pixGenerator, self).__init__()

        self.downsample_layers = []
        # Downsampling
        in_features = 3
        out_features = 64
        
        input = nn.Sequential(*self.downsample(in_features,out_features,False))
        self.downsample_layers.append(input) #(128, 128, 64)

        in_features = out_features
        out_features = out_features * 2
        
        input = nn.Sequential(*self.downsample(in_features,out_features))
        self.downsample_layers.append(input) #(64, 64, 128)

        in_features = out_features
        out_features = out_features * 2
        
        input = nn.Sequential(*self.downsample(in_features,out_features))
        self.downsample_layers.append(input) # (32, 32, 256)

        in_features = out_features
        out_features = out_features * 2

        input = nn.Sequential(*self.downsample(in_features,out_features))
        self.downsample_layers.append(input) # (16, 16, 512)

        in_features = out_features

        self.downsample_layers.append(nn.Sequential(*self.downsample(in_features,out_features))) # (8, 8, 512)
        self.downsample_layers.append(nn.Sequential(*self.downsample(in_features,out_features))) # (4, 4, 512)
        self.downsample_layers.append(nn.Sequential(*self.downsample(in_features,out_features))) # (2, 2, 512)
        self.downsample_layers.append(nn.Sequential(*self.downsample(in_features,out_features))) # (1, 1, 512)

        self.downsample_layer = nn.Sequential(*self.downsample_layers)

        self.updsample_layers = []

        self.updsample_layers.append(nn.Sequential(*self.upsample(in_features,out_features, apply_dropout=True))) # (2, 2, 512)

        in_features = out_features * 2 # concat 1024

        self.updsample_layers.append(nn.Sequential(*self.upsample(in_features,out_features, apply_dropout=True))) # (4, 4, 512)
        self.updsample_layers.append(nn.Sequential(*self.upsample(in_features,out_features, apply_dropout=True))) # (8, 8, 512)
        self.updsample_layers.append(nn.Sequential(*self.upsample(in_features,out_features))) # (16, 16, 512)

        out_features = out_features // 2 # 256

        self.updsample_layers.append(nn.Sequential(*self.upsample(in_features,out_features))) # (32, 32, 256)

        in_features = out_features * 2 # 512
        out_features = out_features // 2 # 128

        self.updsample_layers.append(nn.Sequential(*self.upsample(in_features,out_features))) # (64, 64, 128)

        in_features = out_features * 2 # 256
        out_features = out_features // 2 #64

        self.updsample_layers.append(nn.Sequential(*self.upsample(in_features,out_features))) # (128, 128, 64)
        
        in_features = out_features * 2
        out_features = output_nc

        self.updsample_layer = nn.Sequential(*self.updsample_layers)

        self.output_layer = nn.Sequential(
                                           nn.ConvTranspose2d(in_features, out_features, 4, stride=2, padding=1),
                                           nn.Tanh(),
        )

    def downsample(self, in_features,out_features, apply_batchnorm=True):
      layerList = []
      layerList.append(nn.Conv2d(in_features, out_features, 4, stride=2, padding=1, bias=False))
      if apply_batchnorm:
        layerList.append(nn.BatchNorm2d(out_features))
      layerList.append(nn.LeakyReLU(0.3, inplace=True))

      return layerList

    def upsample(self, in_features,out_features, apply_dropout=True):
      layerList = []
      layerList.append(nn.ConvTranspose2d(in_features, out_features, 4, stride=2, padding=1, bias=False))

      
      layerList.append(nn.BatchNorm2d(out_features))
      if apply_dropout:
        layerList.append(nn.Dropout(0.2))
      layerList.append(nn.LeakyReLU(0.3, inplace=True))

      return layerList

    def forward(self, x):
      
      down_result = []
      for i, down in enumerate(self.downsample_layers):
        x = down(x)
        down_result.append(x)
      down_result = reversed(down_result[:-1])
      for up, down in zip(self.updsample_layers, down_result):
        x = up(x)
        x = torch.cat([x, down], dim=1)

      x = self.output_layer(x)
      return x

# %%
class Pix2pixDiscriminator(nn.Module):
    def __init__(self, input_nc):
        super(Pix2pixDiscriminator, self).__init__()

        # A bunch of convolutions one after another
        self.downsample_layers = []
        # Downsampling
        in_features = input_nc * 2
        out_features = 64
        
        input = nn.Sequential(*self.downsample(in_features,out_features,False))
        self.downsample_layers.append(input) #(128, 128, 64)

        in_features = out_features
        out_features = out_features * 2
        
        input = nn.Sequential(*self.downsample(in_features,out_features))
        self.downsample_layers.append(input) #(64, 64, 128)

        in_features = out_features
        out_features = out_features * 2
        
        input = nn.Sequential(*self.downsample(in_features,out_features))
        self.downsample_layers.append(input) # (32, 32, 256)

        self.downsample_layer = nn.Sequential(*self.downsample_layers)

        in_features = out_features
        out_features = out_features * 2

        self.zero_pad = nn.ZeroPad2d(1)

        self.conv1 = nn.Conv2d(in_features, out_features, 4, stride=1, bias=False)

        in_features = out_features

        self.batchnorm = nn.BatchNorm2d(out_features)
        self.leakyRelu = nn.LeakyReLU(0.3, inplace=True)
        self.conv2 = nn.Conv2d(in_features, 1, 4, stride=1)

    def downsample(self, in_features,out_features, apply_batchnorm=True):
      layerList = []
      layerList.append(nn.Conv2d(in_features, out_features, 4, stride=2, padding=1, bias=False))
      if apply_batchnorm:
        layerList.append(nn.BatchNorm2d(out_features))
      layerList.append(nn.LeakyReLU(0.3, inplace=True))

      return layerList

    def forward(self, inputImg, targetImg):
        x = torch.cat((inputImg,targetImg), dim=1)
        x = self.downsample_layer(x)
        x = self.zero_pad(x)
        x = self.conv1(x)
        x = self.batchnorm(x)
        x = self.leakyRelu(x)
        x = self.zero_pad(x)
        x = self.conv2(x)
        return x

# %% [markdown]
# #CycleGan

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_features):
        super(ResidualBlock, self).__init__()

        conv_block = [  nn.ReflectionPad2d(1),
                        nn.Conv2d(in_features, in_features, 3),
                        nn.InstanceNorm2d(in_features),
                        nn.ReLU(inplace=True),
                        nn.Dropout(0.5),
                        nn.ReflectionPad2d(1),
                        nn.Conv2d(in_features, in_features, 3),
                        nn.InstanceNorm2d(in_features)]

        self.conv_block = nn.Sequential(*conv_block)

    def forward(self, x):
        return x + self.conv_block(x)

# %% [markdown]
# ## Generator

# %%
class Generator(nn.Module):
    def __init__(self, input_nc, output_nc, n_residual_blocks=9):
        super(Generator, self).__init__()

        # Initial convolution block       
        model = [   nn.ReflectionPad2d(3),
                    nn.Conv2d(input_nc, 64, 7),
                    nn.InstanceNorm2d(64),
                    nn.ReLU(inplace=True) ]

        # Downsampling
        in_features = 64
        out_features = in_features*2
        for _ in range(2):
            model += [  nn.Conv2d(in_features, out_features, 3, stride=2, padding=1),
                        nn.InstanceNorm2d(out_features),
                        nn.ReLU(inplace=True) ]
            in_features = out_features
            out_features = in_features*2

        # Residual blocks
        for _ in range(n_residual_blocks):
            model += [ResidualBlock(in_features)]

        # Upsampling
        out_features = in_features//2
        for _ in range(2):
            model += [  nn.ConvTranspose2d(in_features, out_features, 3, stride=2, padding=1, output_padding=1),
                        nn.InstanceNorm2d(out_features),
                        nn.ReLU(inplace=True) ]
            in_features = out_features
            out_features = in_features//2

        # Output layer
        model += [  nn.ReflectionPad2d(3),
                    nn.Conv2d(64, output_nc, 7),
                    nn.Tanh() ]

        self.model = nn.Sequential(*model)

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ##Discriminator

# %%
class Discriminator(nn.Module):
  def __init__(self, input_nc):
      super(Discriminator, self).__init__()

      # A bunch of convolutions one after another
      model = [   nn.Conv2d(input_nc, 64, 4, stride=2, padding=1),
                  nn.LeakyReLU(0.2, inplace=True),
                  nn.Dropout(0.2)]

      model += [  nn.Conv2d(64, 128, 4, stride=2, padding=1),
                  nn.InstanceNorm2d(128),
                  nn.LeakyReLU(0.2, inplace=True),
                  nn.Dropout(0.2) ]

      model += [  nn.Conv2d(128, 256, 4, stride=2, padding=1),
                  nn.InstanceNorm2d(256),
                  nn.LeakyReLU(0.2, inplace=True),
                  nn.Dropout(0.2) ]

      model += [  nn.Conv2d(256, 512, 4, 1, 1),
                  nn.InstanceNorm2d(512),
                  nn.LeakyReLU(0.2, inplace=True) ]

      # FCN classification layer
      model += [nn.Conv2d(512, 1, 4, 1, 1)]

      self.model = nn.Sequential(*model)

  def forward(self, x):
    return self.model(x)

# %%
pix2pix_netG = Pix2pixGenerator(3)

default_netG_A2B = Generator(3, 3)
default_netG_B2A = Generator(3, 3)

semi_netG_A2B = Generator(3, 3)
semi_netG_B2A = Generator(3, 3)

# %%
pix2pix_save_folder = f'/content/gdrive/MyDrive/Colab Notebooks/cityspaces/pix2pix/' 
pix2pix_file_name = f'pix2pix_model_2022-05-17 22:44:41.579700+09:00.pth'
pix2pix_checkpoint = torch.load(f'{pix2pix_save_folder}{pix2pix_file_name}', map_location=torch.device('cpu'))
pix2pix_netG.load_state_dict(pix2pix_checkpoint['g_model_state_dict'])
print(pix2pix_checkpoint['epoch'])
# Out:
# 190

# %%
cyclegan_save_folder = f'/content/gdrive/MyDrive/Colab Notebooks/cityspaces/cyclegan/'
cyclegan_file_name = f'cyclegan_model_2022-05-19 10:57:32.132476+09:00.pth'
cycle_gan_checkpoint = torch.load(f'{cyclegan_save_folder}{cyclegan_file_name}', map_location=torch.device('cpu'))
start_epoch = cycle_gan_checkpoint['epoch']
default_netG_A2B.load_state_dict(cycle_gan_checkpoint['netG_A2B_state_dict'])
default_netG_B2A.load_state_dict(cycle_gan_checkpoint['netG_B2A_state_dict'])
print(start_epoch)
# Out:
# 200

# %%
save_model_folder = f'/content/gdrive/MyDrive/Colab Notebooks/cityspaces/semi_cyclegan/'
file_name = f'semi_cyclegan_model_2022-05-20 19:43:16.650983+09:00.pth_200epochs.pth'
checkpoint = torch.load(f'{save_model_folder}{file_name}', map_location=torch.device('cpu'))
start_epoch = checkpoint['epoch']
semi_netG_A2B.load_state_dict(checkpoint['netG_A2B_state_dict'])
semi_netG_B2A.load_state_dict(checkpoint['netG_B2A_state_dict'])
print(start_epoch)
# Out:
# 200

# %%
device = 'cuda' if torch.cuda.is_available() else  'cpu'
device
# Out:
# 'cuda'

# %%
val_iter = iter(val_loader)

pix2pix_netG.to(device)
default_netG_A2B.to(device)
default_netG_B2A.to(device)
semi_netG_A2B.to(device)
semi_netG_B2A.to(device)

pix2pix_netG.eval()
default_netG_A2B.eval()
default_netG_B2A.eval()
semi_netG_A2B.eval()
semi_netG_B2A.eval()
print("done")
# Out:
# done

# %%
for _ in range(50):
  inputA, inputB = next(val_iter)


  with torch.no_grad():
    inputA = inputA.to(device)
    inputB = inputB.to(device)

    pix2pix_fake_B = pix2pix_netG(inputA)
    default_fake_B = default_netG_A2B(inputA)
    semi_fake_B = semi_netG_A2B(inputA)

    #default_fake_A = tensor_to_image(default_netG_B2A(inputB))
    #semi_fake_A = tensor_to_image(semi_netG_B2A(inputB))

    fig = plt.figure(figsize=(30,30))
    fig.add_subplot(141)
    plt.imshow(tensor_to_image(inputB))
    fig.add_subplot(142)
    plt.imshow(tensor_to_image(pix2pix_fake_B))
    fig.add_subplot(143)
    plt.imshow(tensor_to_image(default_fake_B))
    fig.add_subplot(144)
    plt.imshow(tensor_to_image(semi_fake_B))
   
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #Segmentation Labels

# %%
label_colors = {}
label_colors['sidewalk'] = [244,35,232]
label_colors['building'] = [70, 70, 70]
label_colors['wall'] = [102,102,156]
label_colors['fence'] = [190,153,153]
label_colors['pole'] = [153,153,153]
label_colors['traffic light'] = [250,170, 30]
label_colors['traffic sign'] = [220,220,0]
label_colors['vegetation'] = [107,142, 35]
label_colors['terrain'] = [152,251,152]
label_colors['sky'] = [70,130,180]
label_colors['person'] = [220, 20, 60]
label_colors['rider'] = [255, 0, 0]
label_colors['car'] = [0, 0,142]
label_colors['truck'] = [0, 0, 70]
label_colors['bus'] = [0, 60,100]
label_colors['train'] = [0, 80,100]
label_colors['motorcycle'] = [0, 0,230]
label_colors['bicycle	'] = [119, 11, 32]
len(label_colors)
# Out:
# 18

# %%
def make_label_map(image):
  H, W, C = image.shape
  feature_map = np.zeros((H,W,1)).astype(np.uint)
  for h in range(H):
    for w in range(W):
      label_index = 0
      min_distance = float("inf")
      img_color = image[h, w, :]
      for i, label in enumerate(label_colors.values()):
        distance = ((img_color - label) ** 2).sum()
        if min_distance > distance:
          label_index = i
          min_distance = distance
      feature_map[h, w, 0] = label_index
  return feature_map

# %%
def label_map_to_image(label_map):
  H, W, C = label_map.shape
  label_values = list(label_colors.values())
  result_image = np.zeros((H, W, 3)).astype(np.uint)
  for h in range(H):
    for w in range(W):
      result_image[h,w,:] = label_values[label_map[h,w,0]]
  return result_image

# %%
def get_pixel_accuracy(target_label, input_label):
  if target_label.shape != input_label.shape:
    print("Input Shape Error!")
    return
  H, W, C = target_label.shape
  t_i = H * W
  correct_num = np.count_nonzero(target_label == input_label)
  return correct_num / t_i

# %%
def make_label_map_by_torch(image_tensor):
  H, W, C = image_tensor.shape
  device = image_tensor.get_device()
  feature_num = len(label_colors.values())

  
  label_tensor = torch.Tensor(list(label_colors.values())).view(feature_num,1,1,3).repeat(1,H,W,1).to(device)
  image_tensor = torch.unsqueeze(image_tensor, 0).repeat(feature_num,1,1,1).to(device)

  cal_result = (image_tensor - label_tensor).pow(2).sum(-1)
  _, ii = torch.min(cal_result, 0)

  return ii

# %%
def batch_tensor_to_image_tensor(input):
  result = input[0]
  result = (result * 0.5) + 0.5
  result = torch.permute(result, (1,2,0))
  return result * 255.

# %%
def label_tensor_map_to_image(label_map):
  label_map = np.expand_dims(label_map.cpu().numpy(), -1)

  H, W,C = label_map.shape
  label_values = list(label_colors.values())
  result_image = np.zeros((H, W, 3)).astype(np.uint)
  for h in range(H):
    for w in range(W):
      result_image[h,w,:] = label_values[label_map[h,w]]
  return result_image

# %%
def get_pixel_accuracy_by_tensor(target_label, input_label):
  if target_label.shape != input_label.shape:
    print("Input Shape Error!")
    return
  H, W = target_label.shape
  t_i = H * W
  correct_num = torch.count_nonzero(target_label == input_label)
  return correct_num / t_i

# %%
from numpy.lib.arraysetops import union1d
def get_iou_by_tensor(target_label, input_label):
  if target_label.shape != input_label.shape:
    print("Input Shape Error!")
    return
  class_list= torch.unique(target_label)
  class_num = len(class_list)
  H, W = target_label.shape
  class_iou = 0
  for i in class_list:
    target_i = target_label == i
    label_i = input_label == i
    num_target_i = torch.count_nonzero(target_i)
    num_label_i = torch.count_nonzero(label_i)
    intersection = torch.count_nonzero((target_i == True) & (label_i == True))
    union = num_target_i +  num_label_i - intersection
    if union != 0:
      class_iou += intersection / union
  result = class_iou / class_num
  return result

# %%
arr = torch.Tensor([[1,2,3,4,5],[7,8,9,9,0]])
arr2 = torch.Tensor([[1,2,3,9,5],[7,8,9,0,0]])
get_iou_by_tensor(arr, arr2)
# Out:
# tensor(0.7593)

# %%
from tqdm import tqdm
tqdm_var = tqdm(val_loader)
acc_pix2pix_list = []
iou_pix2pix_list = []
acc_cyclegan_list = []
iou_cyclegan_list = []
acc_semi_cyclegan_list = []
iou_semi_cyclegan_list = []
with torch.no_grad():
  for inputA, inputB in tqdm_var:
    inputA = inputA.to(device)
    inputB = inputB.to(device)

    pix2pix_fake_B = pix2pix_netG(inputA)
    cyclegan_fake_B = default_netG_A2B(inputA)
    semi_cyclegan_fake_B = semi_netG_A2B(inputA)

    input_label_map = make_label_map_by_torch(batch_tensor_to_image_tensor(inputB))
    pix2pix_label_map = make_label_map_by_torch(batch_tensor_to_image_tensor(pix2pix_fake_B))
    cyclegan_label_map = make_label_map_by_torch(batch_tensor_to_image_tensor(cyclegan_fake_B))
    semi_cyclegan_label_map = make_label_map_by_torch(batch_tensor_to_image_tensor(semi_cyclegan_fake_B))
  
    acc_pix2pix = get_pixel_accuracy_by_tensor(input_label_map, pix2pix_label_map)
    iou_pix2pix = get_iou_by_tensor(input_label_map, pix2pix_label_map)
    acc_cyclegan = get_pixel_accuracy_by_tensor(input_label_map, cyclegan_label_map)
    iou_cyclegan = get_iou_by_tensor(input_label_map, cyclegan_label_map)
    acc_semi_cyclegan = get_pixel_accuracy_by_tensor(input_label_map, semi_cyclegan_label_map)
    iou_semi_cyclegan = get_iou_by_tensor(input_label_map, semi_cyclegan_label_map)
    
    acc_pix2pix_list.append(acc_pix2pix)
    iou_pix2pix_list.append(iou_pix2pix)
    acc_cyclegan_list.append(acc_cyclegan)
    iou_cyclegan_list.append(iou_cyclegan)
    acc_semi_cyclegan_list.append(acc_semi_cyclegan)
    iou_semi_cyclegan_list.append(iou_semi_cyclegan)
# Out:
# 100%|██████████| 500/500 [00:36<00:00, 13.71it/s]

# %%
pix2pix_pixel_acc = sum(acc_pix2pix_list) / len(acc_pix2pix_list) 
cyclegan_pixel_acc = sum(acc_cyclegan_list) / len(acc_cyclegan_list) 
semi_cyclegan_pixel_acc = sum(acc_semi_cyclegan_list) / len(acc_semi_cyclegan_list)
pix2pix_pixel_acc, cyclegan_pixel_acc, semi_cyclegan_pixel_acc
# Out:
# (tensor(0.7797, device='cuda:0'),
#  tensor(0.5233, device='cuda:0'),
#  tensor(0.8264, device='cuda:0'))

# %%
pix2pix_iou = sum(iou_pix2pix_list) / len(iou_pix2pix_list) 
cyclegan_iou = sum(iou_cyclegan_list) / len(iou_cyclegan_list) 
semi_cyclegan_iou = sum(iou_semi_cyclegan_list) / len(iou_semi_cyclegan_list) 
pix2pix_iou,cyclegan_iou ,semi_cyclegan_iou
# Out:
# (tensor(0.2874, device='cuda:0'),
#  tensor(0.1653, device='cuda:0'),
#  tensor(0.3336, device='cuda:0'))
